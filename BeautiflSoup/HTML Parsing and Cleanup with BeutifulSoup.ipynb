# %% [markdown]
# # Introduction

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color=black><br>
#
# **What?** HTML Parsing and Cleanup with BeutifulSoup
#
# <br></font>
# </div>

# %% [markdown]
# # What is Beautifulsoup?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - BeautifulSoup is one of the many libraries which allow us to scrape web pages.
# - **Alternatives** includs: scrapy & selenium.
#
# <br></font>
# </div>

# %% [markdown]
# # Project's goal

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - You are building a forum search engine for programming questions. We’ve identified Stack.
# - Overflow as a source and decided to extract question and best-answer pairs from the website.
# - How can we go through the text-extraction step in this case? If we observe the HTML markup of a typical Stack Overflow question page, we notice that questions and answers have special tags associated with them.
#
# <br></font>
# </div>

# %% [markdown]
# # Import modules

# %%
from pprint import pprint
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# # Identify source/dataset

# %%
#specify the url
myurl = "https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" 
#query the website so that it returns a html page  
html = urlopen(myurl).read() 
# parse the html in the 'html' variable, and store it in Beautiful Soup format
soupified = BeautifulSoup(html, 'html.parser')

# %%
pprint(soupified.prettify())
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="html__responsive html__fixed-top-bar" itemscope="" '
#  'itemtype="https://schema.org/QAPage">\n'
#  ' <head>\n'
#  '  <title>\n'
#  '   datetime - How to get the current time in Python - Stack Overflow\n'
#  '  </title>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" '
#  'rel="shortcut icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="apple-touch-icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="image_src"/>\n'
#  '  <link href="/opensearch.xml" rel="search" title="Stack Overflow" '
#  'type="application/opensearchdescription+xml"/>\n'
#  '  <link '
#  'href="https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" '
#  'rel="canonical">\n'
#  '   <meta content="width=device-width, height=device-height, '
#  'initial-scale=1.0, minimum-scale=1.0" name="viewport"/>\n'
#  '   <meta content="website" property="og:type">\n'
#  '    <meta '
#  'content="https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" '
#  'property="og:url"/>\n'
#  '    <meta content="Stack Overflow" property="og:site_name"/>\n'
#  '    <meta '
#  'content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" '
#  'itemprop="image primaryImageOfPage" property="og:image"/>\n'
#  '    <meta content="summary" name="twitter:card"/>\n'
#  '    <meta content="stackoverflow.com" name="twitter:domain"/>\n'
#  '    <meta content="How to get the current time in Python" itemprop="name" '
#  'name="twitter:title" property="og:title"/>\n'
#  '    <meta content="What is the module/method used to get the current time?" '
#  'itemprop="description" name="twitter:description" '
#  'property="og:description"/>\n'
#  '    <script '
#  'src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js">\n'
#  '    </script>\n'
#  '    <script src="https://cdn.sstatic.net/Js/stub.en.js?v=089138ad4356">\n'
#  '    </script>\n'
#  '    <link href="https://cdn.sstatic.net/Shared/stacks.css?v=f5e0a087a500" '
#  'rel="stylesheet" type="text/css"/>\n'
#  '    <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=8750dd6b25a4" '
#  'rel="stylesheet" type="text/css"/>\n'
#  '    <link href="/feeds/question/415511" rel="alternate" title="Feed for '
#  'question \'How to get the current time in Python\'" '
#  'type="application/atom+xml"/>\n'
#  '    <script>\n'
#  '     StackExchange.using("StackExchange.misc.copy", function () {\r\n'
#  '                    StackExchange.misc.copy.addCopyEventListeners(\r\n'
#  '                        "|python|datetime|time|",\r\n'
#  '                        0,\r\n'
#  '                        415511,\r\n'
#  '                        46646\r\n'
#  '                    )\r\n'
#  '                })\n'
#  '    </script>\n'
#  '    <meta content="US" name="twitter:app:country"/>\n'
#  '    <meta content="Stack Exchange iOS" name="twitter:app:name:iphone"/>\n'
#  '    <meta content="871299723" name="twitter:app:id:iphone"/>\n'
#  '    <meta '
#  'content="se-zaphod://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" '
#  'name="twitter:app:url:iphone"/>\n'
#  '    <meta content="Stack Exchange iOS" name="twitter:app:name:ipad"/>\n'
#  '    <meta content="871299723" name="twitter:app:id:ipad"/>\n'
#  '    <meta '
#  'content="se-zaphod://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" '
#  'name="twitter:app:url:ipad"/>\n'
#  '    <meta content="Stack Exchange Android" '
#  'name="twitter:app:name:googleplay"/>\n'
#  '    <meta '
#  'content="https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" '
#  'name="twitter:app:url:googleplay"/>\n'
#  '    <meta content="com.stackexchange.marvin" '
#  'name="twitter:app:id:googleplay"/>\n'
#  '    <script>\n'
#  '     StackExchange.ready(function () {\r\n'
#  '\r\n'
#  '                    StackExchange.using("snippets", function () {\r\n'
#  '                        StackExchange.snippets.initSnippetRenderer();\r\n'
#  '                    });\r\n'
#  '                    \r\n'
#  '                StackExchange.using("postValidation", function () {\r\n'
#  '                    '
#  "StackExchange.postValidation.initOnBlurAndSubmit($('#post-form'), 2, "
#  "'answer');\r\n"
#  '                });\r\n'
#  '\r\n'
#  '\r\n'
#  '                '
#  'StackExchange.question.init({showAnswerHelp:true,totalCommentCount:2,shownCommentCount:2,enableTables:true,questionId:415511});\r\n'
#  '\r\n'
#  '                styleCode();\r\n'
#  '\r\n'
#  "                    StackExchange.realtime.subscribeToQuestion('1', "
#  "'415511');\r\n"
#  '                    StackExchange.using("gps", function () { '
#  "StackExchange.gps.trackOutboundClicks('#content', '.js-post-body'); });\r\n"
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '            });\n'
#  '    </script>\n'
#  '    <link '
#  'href="https://cdn.sstatic.net/Shared/Channels/channels.css?v=2a09da57c2c9" '
#  'rel="stylesheet" type="text/css"/>\n'
#  '    <script>\n'
#  '     '
#  'StackExchange.init({"locale":"en","serverTime":1619511351,"routeName":"Questions/Show","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack '
#  'Overflow","description":"Q&A for professional and enthusiast '
#  'programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"cookieDomain":".stackoverflow.com","childUrl":"https://meta.stackoverflow.com","styleCodeWithHighlightjs":true,"negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"fbab2a5d1b1480c42af1f3f6b6e6cf50449c2b9c42d6c67174fb961987429cf4","tid":"daf29613-b236-9f06-6640-beec9d1010e2","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/stacks-icons","svgIconHash":"7eb510ec72e5"}, '
#  '{"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultBasicMaxTrueUpSeats":250,"defaultFreemiumMaxTrueUpSeats":50,"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"slack":{"sidebarAdDismissCookie":"slack-sidebar-ad","sidebarAdDismissCookieExpirationDays":60.0},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"questions":{"enableQuestionTitleLengthLiveWarning":true,"maxTitleSize":150,"questionTitleLengthStartLiveWarningChars":50},"intercom":{"appId":"inf0secd","hostBaseUrl":"https://stacksnippets.net"},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{"enableTables":true},"legal":{"oneTrustConfigId":"c3d9f1e3-55f3-4eba-b268-46cee4c6789c"},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"elections":{"opaVoteResultsBaseUrl":"https://www.opavote.com/results/"},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});\r\n'
#  '        '
#  'StackExchange.using.setCacheBreakers({"js/adops.en.js":"22a9bd59b1e9","js/ask.en.js":"469e6156d3bf","js/begin-edit-event.en.js":"b6f47dd7a88c","js/copy-transpiled.en.js":"f8f92960ae26","js/cm.en.js":"f6b0f217b5a2","js/events.en.js":"16d1a798637a","js/explore-qlist.en.js":"415c9ef1f829","js/full-anon.en.js":"bd7509bd507a","js/full.en.js":"7c3a033d0ea5","js/help.en.js":"2c6f9524a8ea","js/highlightjs-loader.en.js":"d900e1057a63","js/inline-tag-editing.en.js":"25b51d87329a","js/keyboard-shortcuts.en.js":"e35006ff7113","js/markdown-it-loader.en.js":"1aabf94ff0fd","js/modElections.en.js":"e78bcec7072c","js/mobile.en.js":"c7fc71089b65","js/moderator.en.js":"4f0c65e0a69f","js/postCollections-transpiled.en.js":"e18b28807801","js/post-validation.en.js":"ffe5aacef909","js/prettify-full.en.js":"e8f1d2b5b857","js/question-editor.en.js":"","js/review.en.js":"f5b20d05ad63","js/review-v2-transpiled.en.js":"dba412c74dc7","js/revisions.en.js":"2ae1657f6037","js/stacks-editor.en.js":"d24a978c84c2","js/tageditor.en.js":"0ffdcf3fc9c4","js/tageditornew.en.js":"4aefd93796bc","js/tagsuggestions.en.js":"54e58e1e39f4","js/unlimited-transpiled.en.js":"8389b11ad5bb","js/wmd.en.js":"c4fdefc56e68","js/snippet-javascript-codemirror.en.js":"ee0761d87882"});\r\n'
#  '        StackExchange.using("gps", function() {\r\n'
#  '             StackExchange.gps.init(false);\r\n'
#  '        });\n'
#  '    </script>\n'
#  '    <noscript id="noscript-css">\n'
#  '     <style>\n'
#  '      body,.top-bar{margin-top:1.9em}\n'
#  '     </style>\n'
#  '    </noscript>\n'
#  '   </meta>\n'
#  '  </link>\n'
#  ' </head>\n'
#  ' <body class="question-page unified-theme">\n'
#  '  <div id="notify-container">\n'
#  '  </div>\n'
#  '  <div id="custom-header">\n'
#  '  </div>\n'
#  '  <header class="top-bar js-top-bar top-bar__network">\n'
#  '   <div class="wmx12 mx-auto grid ai-center h100" role="menubar">\n'
#  '    <div class="-main grid--cell">\n'
#  '     <a aria-controls="left-sidebar" aria-expanded="false" '
#  'aria-haspopup="true" class="left-sidebar-toggle p0 ai-center jc-center '
#  'js-left-sidebar-toggle" href="#" role="menuitem">\n'
#  '      <span class="ps-relative">\n'
#  '      </span>\n'
#  '     </a>\n'
#  '     <div class="topbar-dialog leftnav-dialog js-leftnav-dialog dno">\n'
#  '      <div class="left-sidebar js-unpinned-left-sidebar" '
#  'data-can-be="left-sidebar" data-is-here-when="sm">\n'
#  '      </div>\n'
#  '     </div>\n'
#  '     <a class="-logo js-gps-track" '
#  'data-gps-track="top_nav.click({is_current:false, location:2, '
#  'destination:8})" href="https://stackoverflow.com">\n'
#  '      <span class="-img _glyph">\n'
#  '       Stack Overflow\n'
#  '      </span>\n'
#  '     </a>\n'
#  '    </div>\n'
#  '    <ol class="list-reset grid gs4" role="presentation">\n'
#  '     <li class="grid--cell md:d-none">\n'
#  '      <a class="-marketing-link js-gps-track" data-ga=\'["top '
#  'navigation","about menu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:7})" '
#  'href="/company">\n'
#  '       About\n'
#  '      </a>\n'
#  '     </li>\n'
#  '     <li class="grid--cell">\n'
#  '      <a aria-controls="products-popover" class="-marketing-link '
#  'js-gps-track js-products-menu" data-action="s-popover#toggle" '
#  'data-controller="s-popover" data-ga=\'["top navigation","products menu '
#  'click",null,null,null]\' data-gps-track="top_nav.products.click({location:2, '
#  'destination:1})" data-s-popover-placement="bottom" '
#  'data-s-popover-toggle-class="is-selected" href="#">\n'
#  '       Products\n'
#  '      </a>\n'
#  '     </li>\n'
#  '     <li class="grid--cell md:d-none">\n'
#  '      <a class="-marketing-link js-gps-track" data-ga=\'["top '
#  'navigation","learn more - teams",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:7})" '
#  'href="/teams">\n'
#  '       For Teams\n'
#  '      </a>\n'
#  '     </li>\n'
#  '    </ol>\n'
#  '    <div aria-hidden="true" class="s-popover ws2 mtn2 p0" '
#  'id="products-popover" role="menu">\n'
#  '     <div class="s-popover--arrow">\n'
#  '     </div>\n'
#  '     <ol class="list-reset s-anchors s-anchors__inherit">\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" '
#  'data-ga=\'["top navigation","public qa submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:2})" '
#  'href="/questions">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Stack Overflow\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-light">\n'
#  '         Public questions &amp; answers\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" '
#  'data-ga=\'["top navigation","teams submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:3})" '
#  'href="/teams">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Stack Overflow for Teams\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-light">\n'
#  '         Where developers &amp; technologists share private knowledge with '
#  'coworkers\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" '
#  'data-ga=\'["top navigation","jobs submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:9})" '
#  'href="/jobs?so_source=ProductsMenu&amp;so_medium=StackOverflow">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Jobs\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-light">\n'
#  '         Programming &amp; related technical career opportunities\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" '
#  'data-ga=\'["top navigation","talent submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:5})" '
#  'href="https://stackoverflow.com/talent">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Talent\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-light">\n'
#  '         Recruit tech talent &amp; build your employer brand\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-100 js-gps-track" '
#  'data-ga=\'["top navigation","advertising submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:6})" '
#  'href="https://stackoverflow.com/advertising">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Advertising\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-light">\n'
#  '         Reach developers &amp; technologists worldwide\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="bg-black-025 bt bc-black-075 py6 px6 bbr-sm">\n'
#  '       <a class="fc-light d-block py6 px6 h:fc-black-800 js-gps-track" '
#  'data-ga=\'["top navigation","about submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:7})" '
#  'href="/company">\n'
#  '        About the company\n'
#  '       </a>\n'
#  '      </li>\n'
#  '     </ol>\n'
#  '    </div>\n'
#  '    <form action="/search" autocomplete="off" class="grid--cell fl-grow1 '
#  'searchbar px12 js-searchbar" id="search" role="search">\n'
#  '     <div class="ps-relative">\n'
#  '      <input aria-controls="top-search" aria-label="Search" '
#  'autocomplete="off" class="s-input s-input__search js-search-field" '
#  'data-action="focus-&gt;s-popover#show" data-controller="s-popover" '
#  'data-s-popover-placement="bottom-start" maxlength="240" name="q" '
#  'placeholder="Search…" type="text" value=""/>\n'
#  '      <svg aria-hidden="true" class="s-input-icon s-input-icon__search '
#  'svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18">\n'
#  '       <path d="M18 16.5l-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 '
#  '18l1.5-1.5zM12 7A5 5 0 112 7a5 5 0 0110 0z">\n'
#  '       </path>\n'
#  '      </svg>\n'
#  '      <div class="s-popover p0 wmx100 wmn4 sm:wmn-initial '
#  'js-top-search-popover" id="top-search" role="menu">\n'
#  '       <div class="s-popover--arrow">\n'
#  '       </div>\n'
#  '       <div class="js-spinner p24 grid ai-center jc-center d-none">\n'
#  '        <div class="s-spinner s-spinner__sm fc-orange-400">\n'
#  '         <div class="v-visible-sr">\n'
#  '          Loading…\n'
#  '         </div>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '       <span class="v-visible-sr js-screen-reader-info">\n'
#  '       </span>\n'
#  '       <div class="js-ac-results overflow-y-auto hmx3 d-none">\n'
#  '       </div>\n'
#  '       <div aria-describedby="Tips for searching" class="js-search-hints">\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </form>\n'
#  '    <ol class="overflow-x-auto ml-auto -secondary grid ai-center list-reset '
#  'h100 user-logged-out" role="presentation">\n'
#  '     <li class="-item searchbar-trigger">\n'
#  '      <a aria-controls="search" aria-haspopup="true" aria-label="Search" '
#  'class="-link js-searchbar-trigger" href="#" role="button" title="Click to '
#  'show search">\n'
#  '       <svg aria-hidden="true" class="svg-icon iconSearch" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '        <path d="M18 16.5l-5.14-5.18h-.35a7 7 0 10-1.19 1.19v.35L16.5 '
#  '18l1.5-1.5zM12 7A5 5 0 112 7a5 5 0 0110 0z">\n'
#  '        </path>\n'
#  '       </svg>\n'
#  '      </a>\n'
#  '     </li>\n'
#  '     <li class="-ctas">\n'
#  '      <a class="login-link s-btn s-btn__filled py8 js-gps-track" '
#  'data-ga=\'["top navigation","login button click",null,null,null]\' '
#  'data-gps-track="login.click" '
#  'href="https://stackoverflow.com/users/login?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-to-get-the-current-time-in-python" '
#  'rel="nofollow">\n'
#  '       Log in\n'
#  '      </a>\n'
#  '      <a class="login-link s-btn s-btn__primary py8" data-ga=\'["sign '
#  'up","Sign Up Navigation","Header",null,null]\' '
#  'href="https://stackoverflow.com/users/signup?ssrc=head&amp;returnurl=%2fusers%2fstory%2fcurrent" '
#  'rel="nofollow">\n'
#  '       Sign up\n'
#  '      </a>\n'
#  '     </li>\n'
#  '     <li class="js-topbar-dialog-corral" role="presentation">\n'
#  '      <div class="topbar-dialog siteSwitcher-dialog dno" role="menu">\n'
#  '       <div class="header">\n'
#  '        <h3>\n'
#  '         <a href="https://stackoverflow.com">\n'
#  '          current community\n'
#  '         </a>\n'
#  '        </h3>\n'
#  '       </div>\n'
#  '       <div class="modal-content bg-powder-050">\n'
#  '        <ul class="current-site">\n'
#  '         <li class="grid">\n'
#  '          <div class="fl1">\n'
#  '           <a class="current-site-link site-link js-gps-track grid gs8 gsx" '
#  'data-gps-track="site_switcher.click({ item_type:3 })" data-id="1" '
#  'href="https://stackoverflow.com">\n'
#  '            <div class="favicon favicon-stackoverflow site-icon grid--cell" '
#  'title="Stack Overflow">\n'
#  '            </div>\n'
#  '            <span class="grid--cell fl1">\n'
#  '             Stack Overflow\n'
#  '            </span>\n'
#  '           </a>\n'
#  '          </div>\n'
#  '          <div class="related-links">\n'
#  '           <a class="js-gps-track" data-gps-track="site_switcher.click({ '
#  'item_type:14 })" href="https://stackoverflow.com/help">\n'
#  '            help\n'
#  '           </a>\n'
#  '           <a class="js-gps-track" data-gps-track="site_switcher.click({ '
#  'item_type:6 })" '
#  'href="https://chat.stackoverflow.com/?tab=site&amp;host=stackoverflow.com">\n'
#  '            chat\n'
#  '           </a>\n'
#  '          </div>\n'
#  '         </li>\n'
#  '         <li class="related-site grid">\n'
#  '          <div class="L-shaped-icon-container">\n'
#  '           <span class="L-shaped-icon">\n'
#  '           </span>\n'
#  '          </div>\n'
#  '          <a class="site-link js-gps-track grid gs8 gsx" '
#  'data-gps-track="site.switch({ target_site:552, item_type:3 '
#  '}),site_switcher.click({ item_type:4 })" data-id="552" '
#  'href="https://meta.stackoverflow.com">\n'
#  '           <div class="favicon favicon-stackoverflowmeta site-icon '
#  'grid--cell" title="Meta Stack Overflow">\n'
#  '           </div>\n'
#  '           <span class="grid--cell fl1">\n'
#  '            Meta Stack Overflow\n'
#  '           </span>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '        </ul>\n'
#  '       </div>\n'
#  '       <div class="header" id="your-communities-header">\n'
#  '        <h3>\n'
#  '         your communities\n'
#  '        </h3>\n'
#  '       </div>\n'
#  '       <div class="modal-content" id="your-communities-section">\n'
#  '        <div class="call-to-login">\n'
#  '         <a class="login-link js-gps-track" '
#  'data-gps-track="site_switcher.click({ item_type:10 })" '
#  'href="https://stackoverflow.com/users/signup?ssrc=site_switcher&amp;returnurl=%2fusers%2fstory%2fcurrent">\n'
#  '          Sign up\n'
#  '         </a>\n'
#  '         or\n'
#  '         <a class="login-link js-gps-track" '
#  'data-gps-track="site_switcher.click({ item_type:11 })" '
#  'href="https://stackoverflow.com/users/login?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-to-get-the-current-time-in-python">\n'
#  '          log in\n'
#  '         </a>\n'
#  '         to customize your list.\n'
#  '        </div>\n'
#  '       </div>\n'
#  '       <div class="header">\n'
#  '        <h3>\n'
#  '         <a href="https://stackexchange.com/sites">\n'
#  '          more stack exchange communities\n'
#  '         </a>\n'
#  '        </h3>\n'
#  '        <a class="fr" href="https://stackoverflow.blog">\n'
#  '         company blog\n'
#  '        </a>\n'
#  '       </div>\n'
#  '       <div class="modal-content">\n'
#  '        <div class="child-content">\n'
#  '        </div>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </li>\n'
#  '    </ol>\n'
#  '   </div>\n'
#  '  </header>\n'
#  '  <script>\n'
#  '   StackExchange.ready(function () { StackExchange.topbar.init(); });\r\n'
#  'StackExchange.scrollPadding.setPaddingTop(50, 10);\n'
#  '  </script>\n'
#  '  <div class="bg-black-025 bs-sm bt bc-black-100 ps-fixed l0 r0 b0 z-nav '
#  'js-dismissable-hero" data-campaign-name="stk">\n'
#  '   <div class="grid wmx12 mx-auto px8 py12 jc-space-between ai-center '
#  'lg:pl24 lg:pr24 md:fd-column sm:fd-row sm:ai-center">\n'
#  '    <div class="grid--cell fs-body2 fl1 mr16 md:mr0 md:mb12 sm:mb0 '
#  'sm:mr16">\n'
#  '     <p class="mb0">\n'
#  '      <strong>\n'
#  '       Join Stack Overflow\n'
#  '      </strong>\n'
#  '      to learn, share knowledge, and build your career.\n'
#  '     </p>\n'
#  '    </div>\n'
#  '    <div class="grid gs8 gsx ai-center sm:jc-space-between" '
#  'id="openid-buttons">\n'
#  '     <a class="grid--cell s-btn s-btn__filled ws-nowrap" data-ga=\'["sign '
#  'up","Sign Up Navigation","Question Hero",null,null]\' '
#  'href="/users/signup?ssrc=hero&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-to-get-the-current-time-in-python" '
#  'rel="nofollow">\n'
#  '      <span class="sm:d-none">\n'
#  '       Sign up with email\n'
#  '      </span>\n'
#  '      <span class="d-none sm:d-inline">\n'
#  '       Sign up\n'
#  '      </span>\n'
#  '     </a>\n'
#  '     <button class="grid--cell ws-nowrap s-btn s-btn__icon s-btn__google '
#  'ta-center js-major-provider sm:d-none" data-ga=\'["sign up","Sign Up Started '
#  '- Google","Question Hero",null,null]\' '
#  'data-oauthserver="https://accounts.google.com/o/oauth2/auth" '
#  'data-oauthversion="2.0" data-provider="google">\n'
#  '      <svg aria-hidden="true" class="native svg-icon iconGoogle" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '       <path d="M16.51 8H8.98v3h4.3c-.18 1-.74 1.48-1.6 2.04v2.01h2.6a7.8 '
#  '7.8 0 002.38-5.88c0-.57-.05-.66-.15-1.18z" fill="#4285F4">\n'
#  '       </path>\n'
#  '       <path d="M8.98 17c2.16 0 3.97-.72 5.3-1.94l-2.6-2a4.8 4.8 0 '
#  '01-7.18-2.54H1.83v2.07A8 8 0 008.98 17z" fill="#34A853">\n'
#  '       </path>\n'
#  '       <path d="M4.5 10.52a4.8 4.8 0 010-3.04V5.41H1.83a8 8 0 000 '
#  '7.18l2.67-2.07z" fill="#FBBC05">\n'
#  '       </path>\n'
#  '       <path d="M8.98 4.18c1.17 0 2.23.4 3.06 1.2l2.3-2.3A8 8 0 001.83 '
#  '5.4L4.5 7.49a4.77 4.77 0 014.48-3.3z" fill="#EA4335">\n'
#  '       </path>\n'
#  '      </svg>\n'
#  '      Sign up with Google\n'
#  '     </button>\n'
#  '     <button class="grid--cell ws-nowrap s-btn s-btn__icon s-btn__github '
#  'ta-center js-major-provider sm:d-none" data-ga=\'["sign up","Sign Up Started '
#  '- GitHub","Question Hero",null,null]\' '
#  'data-oauthserver="https://github.com/login/oauth/authorize" '
#  'data-oauthversion="2.0" data-provider="github">\n'
#  '      <svg aria-hidden="true" class="svg-icon iconGitHub" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '       <path d="M9 1a8 8 0 00-2.53 '
#  '15.59c.4.07.55-.17.55-.38l-.01-1.49c-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 '
#  '1.08.58 1.23.82.72 1.21 1.87.87 '
#  '2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 '
#  '0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82a7.42 7.42 0 '
#  '014 0c1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 '
#  '0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48l-.01 2.2c0 '
#  '.21.15.46.55.38A8.01 8.01 0 009 1z" fill="#010101">\n'
#  '       </path>\n'
#  '      </svg>\n'
#  '      Sign up with GitHub\n'
#  '     </button>\n'
#  '     <button class="grid--cell ws-nowrap s-btn s-btn__icon s-btn__facebook '
#  'ta-center js-major-provider sm:d-none" data-ga=\'["sign up","Sign Up Started '
#  '- Facebook","Question Hero",null,null]\' '
#  'data-oauthserver="https://www.facebook.com/v2.0/dialog/oauth" '
#  'data-oauthversion="2.0" data-provider="facebook">\n'
#  '      <svg aria-hidden="true" class="svg-icon iconFacebook" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '       <path d="M3 1a2 2 0 00-2 2v12c0 1.1.9 2 2 2h12a2 2 0 002-2V3a2 2 0 '
#  '00-2-2H3zm6.55 16v-6.2H7.46V8.4h2.09V6.61c0-2.07 1.26-3.2 3.1-3.2.88 0 '
#  '1.64.07 1.87.1v2.16h-1.29c-1 0-1.19.48-1.19 1.18V8.4h2.39l-.31 '
#  '2.42h-2.08V17h-2.5z" fill="#4167B2">\n'
#  '       </path>\n'
#  '      </svg>\n'
#  '      Sign up with Facebook\n'
#  '     </button>\n'
#  '     <button class="grid--cell s-btn s-btn__muted s-btn__icon px8 '
#  'js-dismiss" title="Dismiss">\n'
#  '      <svg aria-hidden="true" class="svg-icon iconClear" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '       <path d="M15 4.41L13.59 3 9 7.59 4.41 3 3 4.41 7.59 9 3 13.59 4.41 15 '
#  '9 10.41 13.59 15 15 13.59 10.41 9 15 4.41z">\n'
#  '       </path>\n'
#  '      </svg>\n'
#  '     </button>\n'
#  '    </div>\n'
#  '    <form '
#  'action="/users/signup?ssrc=hero&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-to-get-the-current-time-in-python" '
#  'id="login-form" method="POST">\n'
#  '     <input name="fkey" type="hidden" '
#  'value="fbab2a5d1b1480c42af1f3f6b6e6cf50449c2b9c42d6c67174fb961987429cf4"/>\n'
#  '     <input name="ssrc" type="hidden" value="">\n'
#  '      <input id="oauth_version" name="oauth_version" type="hidden"/>\n'
#  '      <input id="oauth_server" name="oauth_server" type="hidden"/>\n'
#  '      <div id="se-login-fields">\n'
#  '       <input name="legalLinksShown" type="hidden" value="0"/>\n'
#  '      </div>\n'
#  '     </input>\n'
#  '    </form>\n'
#  '    <script>\n'
#  '     StackExchange.ready(function () {\r\n'
#  '                StackExchange.InlineAuth.init();\r\n'
#  '            })\n'
#  '    </script>\n'
#  '   </div>\n'
#  '  </div>\n'
#  '  <script>\n'
#  '   StackExchange.ready(function () {\r\n'
#  '        StackExchange.Hero.init("stk", "a");\r\n'
#  '\r\n'
#  '        var location = 0;\r\n'
#  '        if ($("body").hasClass("questions-page")) {\r\n'
#  '            location = 1;\r\n'
#  '        } else if ($("body").hasClass("question-page")) {\r\n'
#  '            location = 1;\r\n'
#  '        } else if ($("body").hasClass("faq-page")) {\r\n'
#  '            location = 5;\r\n'
#  '        } else if ($("body").hasClass("home-page")) {\r\n'
#  '            location = 3;\r\n'
#  '        }\r\n'
#  '\r\n'
#  "        $('.js-cta-button').click(function () {\r\n"
#  '            StackExchange.using("gps", function () {\r\n'
#  '                StackExchange.gps.track("hero.action", { hero_action_type: '
#  "'cta', location: location }, true);\r\n"
#  '            });\r\n'
#  '        });\r\n'
#  '\r\n'
#  '        // TODO: we should review the class names and whatnot in use here. '
#  'Older heroes use id selectors, the newer\r\n'
#  '        // sticky question hero on SO has a .js-dismiss class instead, but '
#  "it's apparently not used anywhere... \r\n"
#  "        // It's not great. Ideally we'd have a set of classes in the "
#  'partials above that would correspond to \r\n'
#  '        // the behaviours we want here in a more clear way. \r\n'
#  '\r\n'
#  '        // sticky question-page hero at the bottom of the page on SO\r\n'
#  "        $('.js-dismiss').on('click', function () {\r\n"
#  '            StackExchange.using("gps", function () {\r\n'
#  '                StackExchange.gps.track("hero.action", { hero_action_type: '
#  '"close", location: location }, true);\r\n'
#  '            });\r\n'
#  '            StackExchange.Hero.dismiss();\r\n'
#  '            $(".js-dismissable-hero").fadeOut("fast");\r\n'
#  '        });\r\n'
#  '    });\n'
#  '  </script>\n'
#  '  <div class="container">\n'
#  '   <div class="left-sidebar js-pinned-left-sidebar ps-relative" '
#  'data-is-here-when="md lg" id="left-sidebar">\n'
#  '    <div class="left-sidebar--sticky-container js-sticky-leftnav">\n'
#  '     <nav role="navigation">\n'
#  '      <ol class="nav-links">\n'
#  '       <li class="">\n'
#  '        <a aria-controls="" class="pl8 js-gps-track nav-links--link" '
#  'data-controller="" data-gps-track="top_nav.click({is_current:false, '
#  'location:2, destination:8})" data-s-popover-placement="right" href="/">\n'
#  '         <div class="grid ai-center">\n'
#  '          <div class="grid--cell truncate">\n'
#  '           Home\n'
#  '          </div>\n'
#  '         </div>\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <ol class="nav-links">\n'
#  '         <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">\n'
#  '          Public\n'
#  '         </li>\n'
#  '         <li class="youarehere">\n'
#  '          <a aria-controls="" class="pl8 js-gps-track nav-links--link '
#  '-link__with-icon" data-controller="" '
#  'data-gps-track="top_nav.click({is_current:true, location:2, destination:1})" '
#  'data-s-popover-placement="right" href="/questions" id="nav-questions">\n'
#  '           <svg aria-hidden="true" class="svg-icon iconGlobe" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '            <path d="M9 1C4.64 1 1 4.64 1 9c0 4.36 3.64 8 8 8 4.36 0 8-3.64 '
#  '8-8 0-4.36-3.64-8-8-8zM8 15.32a6.46 6.46 0 01-4.3-2.74 6.46 6.46 0 '
#  '01-.93-5.01L7 11.68v.8c0 .88.12 1.32 1 '
#  '1.32v1.52zm5.72-2c-.2-.66-1-1.32-1.72-1.32h-1v-2c0-.44-.56-1-1-1H6V7h1c.44 0 '
#  '1-.56 1-1V5h2c.88 0 1.4-.72 1.4-1.6v-.33a6.45 6.45 0 013.83 4.51 6.45 6.45 0 '
#  '01-1.51 5.73v.01z">\n'
#  '            </path>\n'
#  '           </svg>\n'
#  '           <span class="-link--channel-name">\n'
#  '            Questions\n'
#  '           </span>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li class="">\n'
#  '          <a aria-controls="" class="js-gps-track nav-links--link" '
#  'data-controller="" data-gps-track="top_nav.click({is_current:false, '
#  'location:2, destination:2})" data-s-popover-placement="right" href="/tags" '
#  'id="nav-tags">\n'
#  '           <div class="grid ai-center">\n'
#  '            <div class="grid--cell truncate">\n'
#  '             Tags\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li class="">\n'
#  '          <a aria-controls="" class="js-gps-track nav-links--link" '
#  'data-controller="" data-gps-track="top_nav.click({is_current:false, '
#  'location:2, destination:3})" data-s-popover-placement="right" href="/users" '
#  'id="nav-users">\n'
#  '           <div class="grid ai-center">\n'
#  '            <div class="grid--cell truncate">\n'
#  '             Users\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">\n'
#  '          Find a Job\n'
#  '         </li>\n'
#  '         <li class="">\n'
#  '          <a aria-controls="" class="js-gps-track nav-links--link" '
#  'data-controller="" data-gps-track="top_nav.click({is_current:false, '
#  'location:2, destination:6})" data-s-popover-placement="right" '
#  'href="/jobs?so_medium=StackOverflow&amp;so_source=SiteNav" id="nav-jobs">\n'
#  '           <div class="grid ai-center">\n'
#  '            <div class="grid--cell truncate">\n'
#  '             Jobs\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li class="">\n'
#  '          <a aria-controls="" class="js-gps-track nav-links--link" '
#  'data-controller="" data-gps-track="top_nav.click({is_current:false, '
#  'location:2, destination:12})" data-s-popover-placement="right" '
#  'href="/jobs/companies?so_medium=StackOverflow&amp;so_source=SiteNav" '
#  'id="nav-companies">\n'
#  '           <div class="grid ai-center">\n'
#  '            <div class="grid--cell truncate">\n'
#  '             Companies\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '        </ol>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <ol class="nav-links">\n'
#  '         <div class="js-freemium-cta ps-relative">\n'
#  '          <div class="fs-fine tt-uppercase ml8 mt16 mb8 fc-light">\n'
#  '           Teams\n'
#  '          </div>\n'
#  '          <div class="bt bl bb bc-black-075 p12 pb6 fc-black-600 blr-sm '
#  'overflow-hidden">\n'
#  '           <strong class="fc-black-750 mb6">\n'
#  '            Stack Overflow for Teams\n'
#  '           </strong>\n'
#  '           – Collaborate and share knowledge with a private group.\n'
#  '           <img alt="" class="wmx100 mx-auto my8 h-auto d-block" '
#  'height="114" '
#  'src="https://cdn.sstatic.net/Img/teams/teams-illo-free-sidebar-promo.svg?v=47faa659a05e" '
#  'width="139"/>\n'
#  '           <a class="w100 s-btn s-btn__primary s-btn__xs js-gps-track" '
#  'data-ga=\'["teams left navigation - anonymous","left nav free '
#  'cta","stackoverflow.com/teams/create/free",null,null]\' '
#  'data-gps-track="teams.create.left-sidenav.click({ Action: 6 })" '
#  'href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta">\n'
#  '            Create a free Team\n'
#  '           </a>\n'
#  '           <a class="w100 s-btn s-btn__muted s-btn__xs js-gps-track" '
#  'data-ga=\'["teams left navigation - anonymous","left nav free '
#  'cta","stackoverflow.com/teams",null,null]\' '
#  'data-gps-track="teams.create.left-sidenav.click({ Action: 5 })" '
#  'href="https://stackoverflow.com/teams">\n'
#  '            What is Teams?\n'
#  '           </a>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '         <li class="grid ai-center jc-space-between ml8 mt24 mb4 '
#  'js-create-team-cta d-none">\n'
#  '          <div class="grid--cell tt-uppercase fs-fine fc-light">\n'
#  '           Teams\n'
#  '          </div>\n'
#  '          <div class="grid--cell fs-fine fc-light mr4">\n'
#  '           <a aria-controls="popover-teams-create-cta" class="s-link '
#  's-link__inherit js-gps-track" data-action="s-popover#toggle" '
#  'data-controller="s-popover" data-ga=\'["teams left navigation - '
#  'anonymous","left nav show teams info",null,null,null]\' '
#  'data-gps-track="teams.create.left-sidenav.click({ Action: ShowInfo })" '
#  'data-s-popover-placement="bottom-start" '
#  'data-s-popover-toggle-class="is-selected" href="javascript:void(0)" '
#  'role="button">\n'
#  '            What’s this?\n'
#  '           </a>\n'
#  '          </div>\n'
#  '         </li>\n'
#  '         <li class="ps-relative js-create-team-cta d-none">\n'
#  '          <a class="pl8 js-gps-track nav-links--link" data-ga=\'["teams left '
#  'navigation - anonymous","left nav team '
#  'click","stackoverflow.com/teams/create/free",null,null]\' '
#  'data-gps-track="teams.create.left-sidenav.click({ Action: '
#  'FreemiumTeamsCreateClick })" '
#  'href="https://stackoverflow.com/teams/create/free?utm_source=so-owned&amp;utm_medium=side-bar&amp;utm_campaign=campaign-38&amp;utm_content=cta" '
#  'title="Stack Overflow for Teams is a private, secure spot for your '
#  'organization\'s questions and answers.">\n'
#  '           <div class="grid ai-center">\n'
#  '            <div class="grid--cell s-avatar va-middle bg-orange-400">\n'
#  '             <div class="s-avatar--letter mtn1">\n'
#  '              <svg aria-hidden="true" class="svg-icon iconBriefcaseSm" '
#  'height="14" viewbox="0 0 14 14" width="14">\n'
#  '               <path d="M4 3a1 1 0 011-1h4a1 1 0 011 1v1h.5c.83 0 1.5.67 1.5 '
#  '1.5v5c0 .83-.67 1.5-1.5 1.5h-7A1.5 1.5 0 012 10.5v-5C2 4.67 2.67 4 3.5 '
#  '4H4V3zm5 1V3H5v1h4z">\n'
#  '               </path>\n'
#  '              </svg>\n'
#  '             </div>\n'
#  '             <svg aria-hidden="true" class="native s-avatar--badge svg-icon '
#  'iconShieldXSm" height="10" viewbox="0 0 9 10" width="9">\n'
#  '              <path d="M0 1.84L4.5 0 9 1.84v3.17C9 7.53 6.3 10 4.5 10 2.7 10 '
#  '0 7.53 0 5.01V1.84z" fill="var(--white)">\n'
#  '              </path>\n'
#  '              <path d="M1 2.5L4.5 1 8 2.5v2.51C8 7.34 5.34 9 4.5 9 3.65 9 1 '
#  '7.34 1 5.01V2.5zm2.98 3.02L3.2 7h2.6l-.78-1.48a.4.4 0 '
#  '01.15-.38c.34-.24.73-.7.73-1.14 0-.71-.5-1.23-1.41-1.23-.92 0-1.39.52-1.39 '
#  '1.23 0 .44.4.9.73 1.14.12.08.18.23.15.38z" fill="var(--black-500)">\n'
#  '              </path>\n'
#  '             </svg>\n'
#  '            </div>\n'
#  '            <div class="grid--cell pl6">\n'
#  '             Create free Team\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '        </ol>\n'
#  '       </li>\n'
#  '      </ol>\n'
#  '     </nav>\n'
#  '    </div>\n'
#  '    <div aria-hidden="true" class="s-popover" id="popover-teams-create-cta" '
#  'role="menu">\n'
#  '     <div class="s-popover--arrow">\n'
#  '     </div>\n'
#  '     <div class="ps-relative overflow-hidden">\n'
#  '      <p class="mb2">\n'
#  '       <strong>\n'
#  '        Teams\n'
#  '       </strong>\n'
#  '      </p>\n'
#  '      <p class="mb12 fs-caption fc-black-400">\n'
#  '       Q&amp;A for work\n'
#  '      </p>\n'
#  '      <p class="mb12 fs-caption fc-medium">\n'
#  '       Connect and share knowledge within a single location that is '
#  'structured and easy to search.\n'
#  '      </p>\n'
#  '      <a class="js-gps-track s-btn s-btn__primary s-btn__xs" '
#  'data-ga=\'["teams left navigation - anonymous","left nav '
#  'cta","stackoverflow.com/teams",null,null]\' '
#  'data-gps-track="teams.create.left-sidenav.click({ Action: CtaClick })" '
#  'href="https://stackoverflow.com/teams">\n'
#  '       Learn more\n'
#  '      </a>\n'
#  '     </div>\n'
#  '     <div class="ps-absolute t8 r8">\n'
#  '      <svg aria-hidden="true" class="fc-orange-500 svg-spot spotPeople" '
#  'height="48" viewbox="0 0 48 48" width="48">\n'
#  '       <path d="M13.5 28a4.5 4.5 0 100-9 4.5 4.5 0 000 9zM7 30a1 1 0 '
#  '011-1h11a1 1 0 011 1v5h11v-5a1 1 0 011-1h12a1 1 0 011 1v10a2 2 0 01-2 '
#  '2H33v5a1 1 0 01-1 1H20a1 1 0 01-1-1v-5H8a1 1 0 01-1-1V30zm25-6.5a4.5 4.5 0 '
#  '109 0 4.5 4.5 0 00-9 0zM24.5 34a4.5 4.5 0 100-9 4.5 4.5 0 000 9z" '
#  'opacity=".2">\n'
#  '       </path>\n'
#  '       <path d="M16.4 26.08A6 6 0 107.53 26C5.64 26.06 4 27.52 4 29.45V40a1 '
#  '1 0 001 1h9a1 1 0 100-2h-4v-7a1 1 0 10-2 0v7H6v-9.55c0-.73.67-1.45 '
#  '1.64-1.45H16a1 1 0 00.4-1.92zM12 18a4 4 0 110 8 4 4 0 010-8zm16.47 14a6 6 0 '
#  '10-8.94 0A3.6 3.6 0 0016 35.5V46a1 1 0 001 1h14a1 1 0 '
#  '001-1V35.5c0-1.94-1.64-3.42-3.53-3.5zM20 28a4 4 0 118 0 4 4 0 01-8 0zm-.3 '
#  '6h8.6c1 0 1.7.75 1.7 1.5V45h-2v-7a1 1 0 10-2 0v7h-4v-7a1 1 0 10-2 '
#  '0v7h-2v-9.5c0-.75.7-1.5 1.7-1.5zM42 22c0 1.54-.58 2.94-1.53 4A3.5 3.5 0 0144 '
#  '29.45V40a1 1 0 01-1 1h-9a1 1 0 110-2h4v-7a1 1 0 112 0v7h2v-9.55A1.5 1.5 0 '
#  '0040.48 28H32a1 1 0 01-.4-1.92A6 6 0 1142 22zm-2 0a4 4 0 10-8 0 4 4 0 008 '
#  '0z">\n'
#  '       </path>\n'
#  '       <path d="M17 10a1 1 0 011-1h12a1 1 0 110 2H18a1 1 0 01-1-1zm1-5a1 1 0 '
#  '100 2h12a1 1 0 100-2H18zm-4-4a1 1 0 00-1 1v12a1 1 0 001 1h5.09l4.2 4.2a1 1 0 '
#  '001.46-.04l3.7-4.16H34a1 1 0 001-1V2a1 1 0 00-1-1H14zm1 12V3h18v10h-5a1 1 0 '
#  '00-.75.34l-3.3 3.7-3.74-3.75a1 1 0 00-.71-.29H15z" opacity=".35">\n'
#  '       </path>\n'
#  '      </svg>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '   <div class="snippet-hidden" id="content">\n'
#  '    <div itemprop="mainEntity" itemscope="" '
#  'itemtype="https://schema.org/Question">\n'
#  '     <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'itemprop="image"/>\n'
#  '     <div class="inner-content clearfix">\n'
#  '      <div class="grid sm:fd-column" id="question-header">\n'
#  '       <h1 class="fs-headline1 ow-break-word mb8 grid--cell fl1" '
#  'itemprop="name">\n'
#  '        <a class="question-hyperlink" '
#  'href="/questions/415511/how-to-get-the-current-time-in-python">\n'
#  '         How to get the current time in Python\n'
#  '        </a>\n'
#  '       </h1>\n'
#  '       <div class="ml12 aside-cta grid--cell print:d-none sm:ml0 sm:mb12 '
#  'sm:order-first sm:as-end">\n'
#  '        <a class="ws-nowrap s-btn s-btn__primary" href="/questions/ask">\n'
#  '         Ask Question\n'
#  '        </a>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '      <div class="grid fw-wrap pb8 mb16 bb bc-black-075">\n'
#  '       <div class="grid--cell ws-nowrap mr16 mb8" title="2009-01-06 '
#  '04:54:23Z">\n'
#  '        <span class="fc-light mr2">\n'
#  '         Asked\n'
#  '        </span>\n'
#  '        <time datetime="2009-01-06T04:54:23" itemprop="dateCreated">\n'
#  '         12 years, 3 months ago\n'
#  '        </time>\n'
#  '       </div>\n'
#  '       <div class="grid--cell ws-nowrap mr16 mb8">\n'
#  '        <span class="fc-light mr2">\n'
#  '         Active\n'
#  '        </span>\n'
#  '        <a class="s-link s-link__inherit" href="?lastactivity" '
#  'title="2021-04-11 11:46:13Z">\n'
#  '         15 days ago\n'
#  '        </a>\n'
#  '       </div>\n'
#  '       <div class="grid--cell ws-nowrap mb8" title="Viewed 3,579,977 '
#  'times">\n'
#  '        <span class="fc-light mr2">\n'
#  '         Viewed\n'
#  '        </span>\n'
#  '        3.6m times\n'
#  '       </div>\n'
#  '      </div>\n'
#  '      <div aria-label="question and answers" id="mainbar" role="main">\n'
#  '       <div class="question" data-ownerid="46646" data-questionid="415511" '
#  'data-score="3218" id="question">\n'
#  '        <style>\n'
#  '        </style>\n'
#  '        <div class="js-zone-container zone-container-main">\n'
#  '         <div class="everyonelovesstackoverflow '
#  'everyoneloves__top-leaderboard everyoneloves__leaderboard" id="dfp-tlb">\n'
#  '         </div>\n'
#  '         <div class="js-report-ad-button-container" style="width: 728px">\n'
#  '         </div>\n'
#  '        </div>\n'
#  '        <div class="post-layout">\n'
#  '         <div class="votecell post-layout--left">\n'
#  '          <div class="js-voting-container grid jc-center fd-column '
#  'ai-stretch gs4 fc-black-200" data-post-id="415511">\n'
#  '           <button aria-label="Up vote" aria-pressed="false" '
#  'class="js-vote-up-btn grid--cell s-btn s-btn__unset c-pointer" '
#  'data-controller="s-tooltip" data-s-tooltip-placement="right" '
#  'data-selected-classes="fc-theme-primary" title="This question shows research '
#  'effort; it is useful and clear">\n'
#  '            <svg aria-hidden="true" class="m0 svg-icon iconArrowUpLg" '
#  'height="36" viewbox="0 0 36 36" width="36">\n'
#  '             <path d="M2 26h32L18 10 2 26z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '           </button>\n'
#  '           <div class="js-vote-count grid--cell fc-black-500 fs-title grid '
#  'fd-column ai-center" data-value="3218" itemprop="upvoteCount">\n'
#  '            3218\n'
#  '           </div>\n'
#  '           <button aria-label="Down vote" aria-pressed="false" '
#  'class="js-vote-down-btn grid--cell s-btn s-btn__unset c-pointer" '
#  'data-controller="s-tooltip" data-s-tooltip-placement="right" '
#  'data-selected-classes="fc-theme-primary" title="This question does not show '
#  'any research effort; it is unclear or not useful">\n'
#  '            <svg aria-hidden="true" class="m0 svg-icon iconArrowDownLg" '
#  'height="36" viewbox="0 0 36 36" width="36">\n'
#  '             <path d="M2 10h32L18 26 2 10z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '           </button>\n'
#  '           <button aria-label="Bookmark (486)" aria-pressed="false" '
#  'class="js-bookmark-btn s-btn s-btn__unset c-pointer py4 js-gps-track" '
#  'data-controller="s-tooltip" data-gps-track="post.click({ item: 1, priv: 0, '
#  'post_type: 1 })" data-s-tooltip-placement="right" '
#  'data-selected-classes="fc-yellow-600" title="Bookmark this question.">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconBookmark" '
#  'height="18" viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M6 1a2 2 0 00-2 2v14l5-4 5 4V3a2 2 0 00-2-2H6zm3.9 '
#  '3.83h2.9l-2.35 1.7.9 2.77L9 7.59l-2.35 1.7.9-2.76-2.35-1.7h2.9L9 2.06l.9 '
#  '2.77z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <div class="js-bookmark-count mt4" data-value="486">\n'
#  '             486\n'
#  '            </div>\n'
#  '           </button>\n'
#  '           <a aria-label="Timeline" class="js-post-issue grid--cell s-btn '
#  's-btn__unset c-pointer py6 mx-auto" data-controller="s-tooltip" '
#  'data-ks-title="timeline" data-s-tooltip-placement="right" data-shortcut="T" '
#  'href="/posts/415511/timeline" title="Show activity on this post.">\n'
#  '            <svg aria-hidden="true" class="mln2 mr0 svg-icon iconHistory" '
#  'height="18" viewbox="0 0 19 18" width="19">\n'
#  '             <path d="M3 9a8 8 0 113.73 6.77L8.2 14.3A6 6 0 105 9l3.01-.01-4 '
#  '4-4-4h3L3 9zm7-4h1.01L11 9.36l3.22 2.1-.6.93L10 10V5z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '           </a>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '         <div class="postcell post-layout--right">\n'
#  '          <div class="s-prose js-post-body" itemprop="text">\n'
#  '           <p>\n'
#  '            What is the module/method used to get the current time?\n'
#  '           </p>\n'
#  '          </div>\n'
#  '          <div class="mt24 mb12">\n'
#  '           <div class="post-taglist grid gs4 gsy fd-column">\n'
#  '            <div class="grid ps-relative">\n'
#  '             <a class="post-tag" href="/questions/tagged/python" rel="tag" '
#  'title="show questions tagged \'python\'">\n'
#  '              python\n'
#  '             </a>\n'
#  '             <a class="post-tag" href="/questions/tagged/datetime" rel="tag" '
#  'title="show questions tagged \'datetime\'">\n'
#  '              datetime\n'
#  '             </a>\n'
#  '             <a class="post-tag" href="/questions/tagged/time" rel="tag" '
#  'title="show questions tagged \'time\'">\n'
#  '              time\n'
#  '             </a>\n'
#  '            </div>\n'
#  '           </div>\n'
#  '          </div>\n'
#  '          <div class="mb0">\n'
#  '           <div class="mt16 grid gs8 gsy fw-wrap jc-end ai-start pt4 mb16">\n'
#  '            <div class="grid--cell mr16 fl1 w96">\n'
#  '             <div class="js-post-menu pt2" data-post-id="415511">\n'
#  '              <div class="grid d-flex gs8 s-anchors s-anchors__muted '
#  'fw-wrap">\n'
#  '               <div class="grid--cell">\n'
#  '                <a class="js-share-link js-gps-track" '
#  'data-controller="se-share-sheet" data-gps-track="post.click({ item: 2, priv: '
#  '0, post_type: 1 })" data-s-popover-placement="bottom-start" '
#  'data-se-share-sheet-license-name="CC BY-SA 4.0" '
#  'data-se-share-sheet-license-url="https%3a%2f%2fcreativecommons.org%2flicenses%2fby-sa%2f4.0%2f" '
#  'data-se-share-sheet-location="1" data-se-share-sheet-post-type="question" '
#  'data-se-share-sheet-social="facebook twitter devto" '
#  'data-se-share-sheet-subtitle="" data-se-share-sheet-title="Share a link to '
#  'this question" href="/q/415511" itemprop="url" rel="nofollow" title="Short '
#  'permalink to this question">\n'
#  '                 Share\n'
#  '                </a>\n'
#  '               </div>\n'
#  '               <div class="grid--cell">\n'
#  '                <a class="js-suggest-edit-post js-gps-track" '
#  'data-gps-track="post.click({ item: 6, priv: 0, post_type: 1 })" '
#  'href="/posts/415511/edit" title="">\n'
#  '                 Improve this question\n'
#  '                </a>\n'
#  '               </div>\n'
#  '               <div class="grid--cell">\n'
#  '                <button aria-controls="" class="s-btn s-btn__link '
#  'js-follow-post js-follow-question js-gps-track" data-controller="s-tooltip " '
#  'data-gps-track="post.click({ item: 14, priv: 0, post_type: 1 })" '
#  'data-s-popover-placement="bottom" data-s-tooltip-placement="bottom" '
# ...
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://bricks.stackexchange.com" '
#  'title="LEGO® and building block enthusiasts">\n'
#  '          Bricks\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://homebrew.stackexchange.com" '
#  'title="dedicated home brewers and serious enthusiasts">\n'
#  '          Homebrewing\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://martialarts.stackexchange.com" '
#  'title="students and teachers of all martial arts">\n'
#  '          Martial Arts\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://outdoors.stackexchange.com" '
#  'title="people who love being outdoors enjoying nature and wilderness, and '
#  'learning about the required skills and equipment">\n'
#  '          The Great Outdoors\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://poker.stackexchange.com" '
#  'title="serious players and enthusiasts of poker">\n'
#  '          Poker\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '      <div class="site-footer--col site-footer--category js-footer-col" '
#  'data-name="Culture / Recreation">\n'
#  '       <ul class="-list">\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://chess.stackexchange.com" '
#  'title="serious players and enthusiasts of chess">\n'
#  '          Chess\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://sports.stackexchange.com" '
#  'title="participants in team and individual sport activities">\n'
#  '          Sports\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 26 })" '
#  'href="https://stackexchange.com/sites#culturerecreation">\n'
#  '          <strong>\n'
#  '           more (16)\n'
#  '          </strong>\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '      <div class="site-footer--col site-footer--category js-footer-col" '
#  'data-name="Science">\n'
#  '       <ul class="-list">\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://mathoverflow.net" '
#  'title="professional mathematicians">\n'
#  '          MathOverflow\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://math.stackexchange.com" '
#  'title="people studying math at any level and professionals in related '
#  'fields">\n'
#  '          Mathematics\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://stats.stackexchange.com" '
#  'title="people interested in statistics, machine learning, data analysis, '
#  'data mining, and data visualization">\n'
#  '          Cross Validated (stats)\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://cstheory.stackexchange.com" '
#  'title="theoretical computer scientists and researchers in related fields">\n'
#  '          Theoretical Computer Science\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://physics.stackexchange.com" '
#  'title="active researchers, academics and students of physics">\n'
#  '          Physics\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://chemistry.stackexchange.com" '
#  'title="scientists, academics, teachers, and students in the field of '
#  'chemistry">\n'
#  '          Chemistry\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://biology.stackexchange.com" '
#  'title="biology researchers, academics, and students">\n'
#  '          Biology\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '      <div class="site-footer--col site-footer--category js-footer-col" '
#  'data-name="Science">\n'
#  '       <ul class="-list">\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://cs.stackexchange.com" '
#  'title="students, researchers and practitioners of computer science">\n'
#  '          Computer Science\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://philosophy.stackexchange.com" '
#  'title="those interested in the study of the fundamental nature of knowledge, '
#  'reality, and existence">\n'
#  '          Philosophy\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://linguistics.stackexchange.com" '
#  'title="professional linguists and others with an interest in linguistic '
#  'research and theory">\n'
#  '          Linguistics\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://psychology.stackexchange.com" '
#  'title="practitioners, researchers, and students in cognitive science, '
#  'psychology, neuroscience, and psychiatry">\n'
#  '          Psychology &amp; Neuroscience\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://scicomp.stackexchange.com" '
#  'title="scientists using computers to solve scientific problems">\n'
#  '          Computational Science\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 26 })" href="https://stackexchange.com/sites#science">\n'
#  '          <strong>\n'
#  '           more (10)\n'
#  '          </strong>\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '      <div class="site-footer--col site-footer--category js-footer-col" '
#  'data-name="Other">\n'
#  '       <ul class="-list">\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://meta.stackexchange.com" '
#  'title="meta-discussion of the Stack Exchange family of Q&amp;A websites">\n'
#  '          Meta Stack Exchange\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://stackapps.com" title="apps, scripts, '
#  'and development with the Stack Exchange API">\n'
#  '          Stack Apps\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://api.stackexchange.com" '
#  'title="programmatic interaction with Stack Exchange sites">\n'
#  '          API\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="-item">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 25 })" href="https://data.stackexchange.com" '
#  'title="querying Stack Exchange data using SQL">\n'
#  '          Data\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </nav>\n'
#  '    <div class="site-footer--copyright fs-fine">\n'
#  '     <ul class="-list">\n'
#  '      <li class="-item">\n'
#  '       <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link:4 })" href="https://stackoverflow.blog?blb=1">\n'
#  '        Blog\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="-item">\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 31 })" '
#  'href="https://www.facebook.com/officialstackoverflow/">\n'
#  '        Facebook\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="-item">\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 32 })" href="https://twitter.com/stackoverflow">\n'
#  '        Twitter\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="-item">\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 33 })" '
#  'href="https://linkedin.com/company/stack-overflow">\n'
#  '        LinkedIn\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="-item">\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 36 })" '
#  'href="https://www.instagram.com/thestackoverflow">\n'
#  '        Instagram\n'
#  '       </a>\n'
#  '      </li>\n'
#  '     </ul>\n'
#  '     <p class="mt-auto mb24">\n'
#  '      site design / logo © 2021 Stack Exchange Inc; user contributions '
#  'licensed under\n'
#  '      <a href="https://stackoverflow.com/help/licensing">\n'
#  '       cc by-sa\n'
#  '      </a>\n'
#  '      .\n'
#  '      <span id="svnrev">\n'
#  '       rev\xa02021.4.26.39152\n'
#  '      </span>\n'
#  '     </p>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '  </footer>\n'
#  '  <script>\n'
#  '   StackExchange.ready(function () { '
#  'StackExchange.responsiveness.addSwitcher(); })\n'
#  '  </script>\n'
#  '  <noscript>\n'
#  '   <div id="noscript-warning">\n'
#  '    Stack Overflow works best with JavaScript enabled\n'
#  '    <img alt="" class="dno" '
#  'src="https://pixel.quantserve.com/pixel/p-c1rF4kxgLUzNc.gif"/>\n'
#  '   </div>\n'
#  '  </noscript>\n'
#  '  <script>\n'
#  '   (function(i, s, o, g, r, a, m) {\r\n'
#  "                i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() { "
#  '(i[r].q = i[r].q || []).push(arguments) }, i[r].l = 1 * new Date(); a = '
#  's.createElement(o),\r\n'
#  '                m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; '
#  'm.parentNode.insertBefore(a, m);\r\n'
#  "            })(window, document, 'script', "
#  "'https://www.google-analytics.com/analytics.js', 'ga');\r\n"
#  '\r\n'
#  '            StackExchange.ready(function () {\r\n'
#  '\r\n'
#  '                StackExchange.ga.init({\r\n'
#  '                    autoLink: '
#  '["stackoverflow.blog","info.stackoverflowsolutions.com","stackoverflowsolutions.com"],\r\n'
#  '                    sendTitles: true,\r\n'
#  '                    tracker: window.ga,\r\n'
#  '                    trackingCodes: [\r\n'
#  "                        'UA-108242619-1'\r\n"
#  '                    ],\r\n'
#  "                        checkDimension: 'dimension42'\r\n"
#  '                });\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  "                    StackExchange.ga.setDimension('dimension2', "
#  "'|python|datetime|time|');\r\n"
#  '\r\n'
#  '\r\n'
#  "                    StackExchange.ga.setDimension('dimension3', "
#  "'Questions/Show');\r\n"
#  '\r\n'
#  '\r\n'
#  '                StackExchange.ga.trackPageView();\r\n'
#  '            });\n'
#  '  </script>\n'
#  '  <div class="ff-sans ps-fixed z-nav-fixed ws4 sm:w-auto p32 sm:p16 '
#  'bg-black-750 fc-white bar-lg b16 l16 r16 js-consent-banner">\n'
#  '   <svg aria-hidden="true" class="mln4 mb24 sm:d-none svg-spot spotCookieLg" '
#  'height="96" style="color: var(--theme-button-filled-background-color)" '
#  'viewbox="0 0 96 96" width="96">\n'
#  '    <path d="M35 45.5a7.5 7.5 0 11-15 0 7.5 7.5 0 0115 0zM63.5 63a7.5 7.5 0 '
#  '100-15 7.5 7.5 0 000 15zm-19 19a7.5 7.5 0 100-15 7.5 7.5 0 000 15z" '
#  'opacity=".2">\n'
#  '    </path>\n'
#  '    <path d="M56.99 2.53a23.1 23.1 0 0114.66 6.15h.01l.01.02c.57.55.61 '
#  '1.27.5 1.74v.07a10.95 10.95 0 01-3.07 4.77 9 9 0 01-6.9 2.5 10.34 10.34 0 '
#  '01-9.72-10.44v-.08a10 10 0 011.03-3.74l.01-.03.02-.02c.28-.5.82-.92 '
#  '1.52-.95.63-.02 1.27-.02 1.93.01zm12.04 7.83a20.1 20.1 0 '
#  '00-12.2-4.83l-.92-.03c-.23.6-.38 1.25-.43 1.94a7.34 7.34 0 006.95 7.34 6 6 0 '
#  '004.64-1.7c.94-.88 1.6-1.9 1.96-2.72zm15.3 8.76a6.84 6.84 0 00-5.09-.24 7.9 '
#  '7.9 0 00-3.28 2.05 1.8 1.8 0 00-.3 1.95l.02.02v.02a15.16 15.16 0 008.74 '
#  '7.47c.64.23 1.32.08 1.8-.33a6.63 6.63 0 '
#  '001.63-1.97l.01-.03.01-.03c1.67-3.5-.12-7.32-3.54-8.91zm-5.5 '
#  '3.28c.36-.25.82-.5 1.35-.67.92-.3 1.92-.35 2.89.1 2.14 1 2.92 3.14 2.11 '
#  '4.88-.12.21-.26.41-.43.6l-.26-.1a12.29 12.29 0 01-5.66-4.81zM32 24a2 2 0 '
#  '11-4 0 2 2 0 014 0zm12 21a2 2 0 11-4 0 2 2 0 014 0zm36 4a2 2 0 11-4 0 2 2 0 '
#  '014 0zm-7 21a2 2 0 11-4 0 2 2 0 014 0zM59 81a2 2 0 11-4 0 2 2 0 014 0zM22 '
#  '63a2 2 0 11-4 0 2 2 0 014 0zm27 7a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 '
#  '10-12 0 6 6 0 0012 0zM33 41a9 9 0 11-18 0 9 9 0 0118 0zm-15 0a6 6 0 1012 0 6 '
#  '6 0 00-12 0zm50 11a9 9 0 11-18 0 9 9 0 0118 0zm-3 0a6 6 0 10-12 0 6 6 0 0012 '
#  '0zM44.08 4.24c.31.48.33 1.09.05 1.58a17.46 17.46 0 00-2.36 8.8c0 9.55 7.58 '
#  '17.24 16.85 17.24 2.97 0 5.75-.78 8.16-2.15a1.5 1.5 0 012.1.66 12.08 12.08 0 '
#  '0011 6.74 12.4 12.4 0 007.85-2.75 1.5 1.5 0 012.38.74A45.76 45.76 0 0192 '
#  '48.16c0 24.77-19.67 44.9-44 44.9S4 72.93 4 48.16C4 25.23 20.84 6.28 42.64 '
#  '3.58a1.5 1.5 0 011.44.66zM40.22 7C21.32 10.71 7 27.7 7 48.16c0 23.17 18.39 '
#  '41.9 41 41.9s41-18.73 41-41.9c0-3.52-.42-6.93-1.22-10.2a15.5 15.5 0 01-7.9 '
#  '2.15c-5.5 0-10.36-2.83-12.97-7.1a19.46 19.46 0 01-8.28 1.85c-11 '
#  '0-19.86-9.1-19.86-20.24 0-2.7.52-5.26 1.45-7.62zM92 91a2 2 0 100-4 2 2 0 000 '
#  '4zM7 8.5a2.5 2.5 0 11-5 0 2.5 2.5 0 015 0zM82.5 90a1.5 1.5 0 100-3 1.5 1.5 0 '
#  '000 3zm9.5-7.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM13.5 8a1.5 1.5 0 100-3 1.5 '
#  '1.5 0 000 3zM80 14.5a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zM53.5 20a1.5 1.5 0 '
#  '100-3 1.5 1.5 0 000 3z">\n'
#  '    </path>\n'
#  '   </svg>\n'
#  '   <p class="fs-body2 fw-bold mb4">\n'
#  '    Your privacy\n'
#  '   </p>\n'
#  '   <p class="mb16 s-anchors s-anchors__inherit s-anchors__underlined">\n'
#  '    By clicking “Accept all cookies”, you agree Stack Exchange can store '
#  'cookies on your device and disclose information in accordance with our\n'
#  '    <a href="https://stackoverflow.com/legal/cookie-policy">\n'
#  '     Cookie Policy\n'
#  '    </a>\n'
#  '    .\n'
#  '   </p>\n'
#  '   <div class="grid gs8 ai-stretch fd-column sm:fd-row">\n'
#  '    <button class="grid--cell s-btn s-btn__primary js-accept-cookies '
#  'js-consent-banner-hide">\n'
#  '     Accept all cookies\n'
#  '    </button>\n'
#  '    <button class="grid--cell s-btn s-btn__filled js-cookie-settings" '
#  'data-consent-popup-loader="banner">\n'
#  '     Customize settings\n'
#  '    </button>\n'
#  '   </div>\n'
#  '  </div>\n'
#  '  <div class="d-none" id="onetrust-consent-sdk">\n'
#  '  </div>\n'
#  '  <div data-controller="s-modal" id="onetrust-banner-sdk">\n'
#  '  </div>\n'
#  '  <div class="d-none" id="ot-pc-content">\n'
#  '  </div>\n'
#  '  <div class="d-none" id="onetrust-style">\n'
#  '  </div>\n'
#  '  <div class="d-none js-consent-banner-version" '
#  'data-consent-banner-version="baseline">\n'
#  '  </div>\n'
#  ' </body>\n'
#  '</html>\n')

# %%
#to get an idea of the html structure of the webpage
pprint(soupified.prettify()[:2000])
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="html__responsive html__fixed-top-bar" itemscope="" '
#  'itemtype="https://schema.org/QAPage">\n'
#  ' <head>\n'
#  '  <title>\n'
#  '   datetime - How to get the current time in Python - Stack Overflow\n'
#  '  </title>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" '
#  'rel="shortcut icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="apple-touch-icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="image_src"/>\n'
#  '  <link href="/opensearch.xml" rel="search" title="Stack Overflow" '
#  'type="application/opensearchdescription+xml"/>\n'
#  '  <link '
#  'href="https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" '
#  'rel="canonical">\n'
#  '   <meta content="width=device-width, height=device-height, '
#  'initial-scale=1.0, minimum-scale=1.0" name="viewport"/>\n'
#  '   <meta content="website" property="og:type">\n'
#  '    <meta '
#  'content="https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" '
#  'property="og:url"/>\n'
#  '    <meta content="Stack Overflow" property="og:site_name"/>\n'
#  '    <meta '
#  'content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" '
#  'itemprop="image primaryImageOfPage" property="og:image"/>\n'
#  '    <meta content="summary" name="twitter:card"/>\n'
#  '    <meta content="stackoverflow.com" name="twitter:domain"/>\n'
#  '    <meta content="How to get the current time in Python" itemprop="name" '
#  'name="twitter:title" property="og:title"/>\n'
#  '    <meta content="What is the module/method used to get the current time?" '
#  'itemprop="description" name="twitter:description" '
#  'property="og:description"/>\n'
#  '    <script '
#  'src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js">\n'
#  '    </script>\n'
#  '    <script src="https://cdn.sstatic.net/Js/stub.en.js?v=089138ad4356">\n'
#  '    </script>\n'
#  '    <link href="https://cdn.sstatic.net/Shared/stacks.css?v=f5e0a087a500" '
#  'rel="stylesheet" type="text/css"/>\n'
#  '    <link href="ht')

# %%
#to get the title of the web page
soupified.title
# Out:
# <title>datetime - How to get the current time in Python - Stack Overflow</title>

# %% [markdown]
# # Parsing the HTML file

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color=black><br>
#
# - Here, we’re relying on our knowledge of the structure of an HTML document to extract what we want from it.
#
# <br></font>
# </div>

# %%
#find the nevessary tag and class which it belongs to
question = soupified.find("div", {"class": "question"}) 
questiontext = question.find("div", {"class": "s-prose js-post-body"})
print("Question: \n", questiontext.get_text().strip())
# Out:
# Question:
#  What is the module/method used to get the current time?

# %% [markdown]
# # Output

# %%
#find the necessary tag and class which it belongs to
answer = soupified.find("div", {"class": "answer"}) 
answertext = answer.find("div", {"class": "s-prose js-post-body"})

print("***********BEST ANSWER STARTS HERE*********")
print(answertext.get_text().strip())
print("***********BEST ANSWER ENDS HERE*********")
# Out:
# ***********BEST ANSWER STARTS HERE*********
# Use:
# >>> import datetime
# >>> datetime.datetime.now()
# datetime.datetime(2009, 1, 6, 15, 8, 24, 78915)
#
# >>> print(datetime.datetime.now())
# 2009-01-06 15:08:24.789150
#
# And just the time:
# >>> datetime.datetime.now().time()
# datetime.time(15, 8, 24, 78915)
#
# >>> print(datetime.datetime.now().time())
# 15:08:24.789150
#
# See the documentation for more information.
# To save typing, you can import the datetime object from the datetime module:
# >>> from datetime import datetime
#
# Then remove the leading datetime. from all of the above.
# ***********BEST ANSWER ENDS HERE*********

# %% [markdown]
# # References

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color=black><br>
#
# - https://github.com/practical-nlp/practical-nlp/blob/master/Ch2/01_WebScraping_using_BeautifulSoup.ipynb
# - Harshit Surana, Practical Natural Language Processing
#
# <br></font>
# </div>
